# %%
filename = "square_wave_mixing"
file = open(filename + ".arb", "r", encoding="ISO-8859-1")
for i in range(9):
    script = file.readline()
script = file.read()
file.close()
script = '#define ' + filename + ' {(byte)(' + script.replace('\n', '.0*0.003891051 + 128), (byte)(')
script = script[:-9] + '}\n'
print(script)
# Out:
# #define square_wave_mixing {(byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(-32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*0.003891051 + 128), (byte)(32767.0*
# ...

# %%
file = open(filename + '.code', "w", encoding="ISO-8859-1")
file.write(script)
file.close()
